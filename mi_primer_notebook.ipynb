# %% [markdown]
# # Code
#
# ## Python
#
# ### Miscelánea

# %%
x = "Hello"
n = 2
l = [1,2,3]

# %%
isinstance(n, (int,float))
# Out:
# True

# %%
x.isdigit() # returns True if all characters in the TEXT are digits
# Out:
# False

# %%
float(n)
str(n)
bool()
# Out:
# 2.0

# %%
max(2,3)
# Out:
# 3

# %%
import math
round(3.55555,2)


x = 3.25555
math.log10(1000)
math.ceil(1000)
# Out:
# 1000
